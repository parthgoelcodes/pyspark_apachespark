# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.table("workspace.default.netflix_titles")

# %%
df.limit(4).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.select(col('title'),col('type'),col('release_year')).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>title</th><th>type</th><th>release_year</th></tr></thead><tbody><tr><td>Dick Johnson Is Dead</td><td>Movie</td><td>2020</td></tr><tr><td>Blood & Water</td><td>TV Show</td><td>2021</td></tr><tr><td>Ganglands</td><td>TV Show</td><td>2021</td></tr><tr><td>Jailbirds New Orleans</td><td>TV Show</td><td>2021</td></tr><tr><td>Kota Factory</td><td>TV Show</td><td>2021</td></tr></tbody></table></div>

# %%
df.limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.select(('show_id'),('title'),('director'),('rating'),('duration')).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>show_id</th><th>title</th><th>director</th><th>rating</th><th>duration</th></tr></thead><tbody><tr><td>s1</td><td>Dick Johnson Is Dead</td><td>Kirsten Johnson</td><td>PG-13</td><td>90 min</td></tr><tr><td>s2</td><td>Blood & Water</td><td>null</td><td>TV-MA</td><td>2 Seasons</td></tr><tr><td>s3</td><td>Ganglands</td><td>Julien Leclercq</td><td>TV-MA</td><td>1 Season</td></tr><tr><td>s4</td><td>Jailbirds New Orleans</td><td>null</td><td>TV-MA</td><td>1 Season</td></tr><tr><td>s5</td><td>Kota Factory</td><td>null</td><td>TV-MA</td><td>2 Seasons</td></tr></tbody></table></div>

# %%
df.select(col('title').alias('movie_title')).limit(5).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>movie_title</th></tr></thead><tbody><tr><td>Dick Johnson Is Dead</td></tr><tr><td>Blood & Water</td></tr><tr><td>Ganglands</td></tr><tr><td>Jailbirds New Orleans</td></tr><tr><td>Kota Factory</td></tr></tbody></table></div>
