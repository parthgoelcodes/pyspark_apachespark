# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
df = spark.table("workspace.default.mega_mart")

df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #withColumnRenamed()
# TO CHANGE THE COLUMN NAME

# %%
df.withColumnRenamed("order_date","date").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #WITHCOLUMN()<BR>
# EXISTING COLUMN CAN BE MODEFIED<BR>
# ALSO CAN ADD A NEW COLUMN

# %% [markdown]
# #To add new column

# %%
df.withColumn("total",(col("quantity"))*(col("price_per_unit"))).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #TO MODEFY A COLUMN

# %%
df.withColumn("quantity",col("quantity")+1).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #TO USE WHEN

# %%
df.withColumn("rating",when(col("quantity")>3,"*****").otherwise("*")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #TO CONVERT NAME FROM SMALL TO CAPITAL

# %%
df.withColumn(("product_category"),
    upper(col("product_category"))
).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# #withColumn(),using lit
# TO ADD A COLUMN WITH CONSTANT VALUE.

# %%
df = df.withColumn("countr_of_delevery",lit("india")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # USE OF REGEXP_REPLACE()
# VE CAN MODEFY THE CONTENT OF AN EXISTING COLUMN

# %%
df.withColumn('payment_method',regexp_replace(col('payment_method'),'UPI','online'))\
    .withColumn('payment_method',regexp_replace(col('payment_method'),'Credit Card','money of bank')).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
